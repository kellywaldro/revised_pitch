# %% [markdown]
# # Cleaning and Merging the Data
#
# Open Streets Data:
#
# - Downloaded from 311 Open Data portal (Vector file of lines for each open street)
# - Calculated mean coordinates for each line (i.e. each registered Open Street) in QGIS
#
# Census data:
#
# - From ACS survey
# - Table B19013 from ACS 5yr (2021) downloaded from Census Reporter
#
# Census Tract data for NYC
#
# - Downloaded [here](https://www.nyc.gov/site/planning/data-maps/open-data/census-download-metadata.page) via NYC portal
# - Originally as a shapefile then converted to csv in QGIS

# %%
import pandas as pd

# %%
! ls
# Out:
# README.md                             mean_coords_table_with_geos.csv
# acs2021_5yr_B19013_14000US36047030600 ny_census_tracts.csv
# analysis.ipynb                        ny_census_tracts.qmd
# clean_merge.ipynb                     open_streets_count.csv
# edited_complaints.csv                 predicted_open_streets
# final_data.csv                        prediction.csv
# geocode.ipynb                         requirements.txt
# mean_coords_table.tsv

# %% [markdown]
# Reading the ACS income data

# %%
income = pd.read_csv('./acs2021_5yr_B19013_14000US36047030600/acs2021_5yr_B19013_14000US36047030600.csv')

# %%
income
# Out:
#                    geoid                               name  B19013001
# 0     14000US36005000100          Census Tract 1, Bronx, NY        NaN  \
# 1     14000US36005000200          Census Tract 2, Bronx, NY    70867.0
# 2     14000US36005000400          Census Tract 4, Bronx, NY    98090.0
# 3     14000US36005001600         Census Tract 16, Bronx, NY    40033.0
# 4     14000US36005001901      Census Tract 19.01, Bronx, NY    55924.0
# ...                  ...                                ...        ...
# 2322  14000US36085030302  Census Tract 303.02, Richmond, NY    85842.0
# 2323  14000US36085031901  Census Tract 319.01, Richmond, NY        NaN
# 2324  14000US36085031902  Census Tract 319.02, Richmond, NY    76066.0
# 2325  14000US36085032300     Census Tract 323, Richmond, NY    86471.0
# 2326  14000US36085990100    Census Tract 9901, Richmond, NY        NaN
#
#       B19013001, Error
# 0                  NaN
# 1              25423.0
# 2              18180.0
# 3               9907.0
# 4              12028.0
# ...                ...
# 2322           18154.0
# 2323               NaN
# 2324           35257.0
# 2325           25095.0
# 2326               NaN
#
# [2327 rows x 4 columns]

# %%
# rename the columns 

# 3rd column is Median Household Income in the Past 12 Months (In 2021 Inflation-adjusted Dollars)

income.rename(columns={'B19013001': 'median_household_income'}, inplace=True)

# %%
income = income[income['median_household_income'] > 0]

# %%
income['geoid'] = income['geoid'].str.replace('14000US', '')
# Out:
# /var/folders/bp/5dzvdsg55xn25gp9vjh1f4xc0000gn/T/ipykernel_28918/2929573091.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   income['geoid'] = income['geoid'].str.replace('14000US', '')

# %%
income['geoid'] = income['geoid'].astype(int)
# Out:
# /var/folders/bp/5dzvdsg55xn25gp9vjh1f4xc0000gn/T/ipykernel_28918/2520246159.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   income['geoid'] = income['geoid'].astype(int)

# %%
income['COUNTY'] = income['geoid'].astype(str).str.slice(2,5).astype(int)
income['TRACT'] = income['geoid'].astype(str).str.slice(5).astype(int)
income
# Out:
# /var/folders/bp/5dzvdsg55xn25gp9vjh1f4xc0000gn/T/ipykernel_28918/4201568212.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   income['COUNTY'] = income['geoid'].astype(str).str.slice(2,5).astype(int)
# /var/folders/bp/5dzvdsg55xn25gp9vjh1f4xc0000gn/T/ipykernel_28918/4201568212.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   income['TRACT'] = income['geoid'].astype(str).str.slice(5).astype(int)
#             geoid                               name  median_household_income
# 1     36005000200          Census Tract 2, Bronx, NY                  70867.0  \
# 2     36005000400          Census Tract 4, Bronx, NY                  98090.0
# 3     36005001600         Census Tract 16, Bronx, NY                  40033.0
# 4     36005001901      Census Tract 19.01, Bronx, NY                  55924.0
# 5     36005001902      Census Tract 19.02, Bronx, NY                  60804.0
# ...           ...                                ...                      ...
# 2320  36085029106  Census Tract 291.06, Richmond, NY                 127671.0
# 2321  36085030301  Census Tract 303.01, Richmond, NY                  95913.0
# 2322  36085030302  Census Tract 303.02, Richmond, NY                  85842.0
# 2324  36085031902  Census Tract 319.02, Richmond, NY                  76066.0
# 2325  36085032300     Census Tract 323, Richmond, NY                  86471.0
#
#       B19013001, Error  COUNTY  TRACT
# 1              25423.0       5    200
# 2              18180.0       5    400
# 3               9907.0       5   1600
# 4              12028.0       5   1901
# 5              12156.0       5   1902
# ...                ...     ...    ...
# 2320           25994.0      85  29106
# 2321            6123.0      85  30301
# 2322           18154.0      85  30302
# 2324           35257.0      85  31902
# 2325           25095.0      85  32300
#
# [2196 rows x 6 columns]

# %% [markdown]
# Although all my data is at the tract level, the notation doesn't match. Fixing that below.

# %%
tracts = pd.read_csv('ny_census_tracts.csv')

# %%
tracts
# Out:
#       CTLabel  BoroCode       BoroName  CT2020  BoroCT2020  CDEligibil
# 0        1.00         1      Manhattan     100     1000100         NaN  \
# 1        2.01         1      Manhattan     201     1000201         NaN
# 2        6.00         1      Manhattan     600     1000600         NaN
# 3       14.01         1      Manhattan    1401     1001401         NaN
# 4       14.02         1      Manhattan    1402     1001402         NaN
# ...       ...       ...            ...     ...         ...         ...
# 2320    77.00         5  Staten Island    7700     5007700         NaN
# 2321    19.02         4         Queens    1902     4001902         NaN
# 2322   171.01         4         Queens   17101     4017101         NaN
# 2323   475.00         4         Queens   47500     4047500         NaN
# 2324   687.00         4         Queens   68700     4068700         NaN
#
#                                                 NTAName NTA2020 CDTA2020
# 0     The Battery-Governors Island-Ellis Island-Libe...  MN0191     MN01  \
# 1                                 Chinatown-Two Bridges  MN0301     MN03
# 2                                 Chinatown-Two Bridges  MN0301     MN03
# 3                                       Lower East Side  MN0302     MN03
# 4                                       Lower East Side  MN0302     MN03
# ...                                                 ...     ...      ...
# 2320                            St. George-New Brighton  SI0101     SI01
# 2321                     Long Island City-Hunters Point  QN0201     QN02
# 2322                            Sunnyside Yards (South)  QN0261     QN02
# 2323                                           Elmhurst  QN0401     QN04
# 2324                                          Rego Park  QN0601     QN06
#
#                                                CDTANAME        GEOID
# 0     MN01 Financial District-Tribeca (CD 1 Equivalent)  36061000100  \
# 1      MN03 Lower East Side-Chinatown (CD 3 Equivalent)  36061000201
# 2      MN03 Lower East Side-Chinatown (CD 3 Equivalent)  36061000600
# 3      MN03 Lower East Side-Chinatown (CD 3 Equivalent)  36061001401
# 4      MN03 Lower East Side-Chinatown (CD 3 Equivalent)  36061001402
# ...                                                 ...          ...
# 2320                 SI01 North Shore (CD 1 Equivalent)  36085007700
# 2321  QN02 Long Island City-Sunnyside-Woodside (CD 2...  36081001902
# 2322  QN02 Long Island City-Sunnyside-Woodside (CD 2...  36081017101
# 2323          QN04 Elmhurst-Corona (CD 4 Approximation)  36081047500
# 2324   QN06 Forest Hills-Rego Park (CD 6 Approximation)  36081068700
#
#         Shape_Leng    Shape_Area
# 0     11023.048501  1.844421e+06
# 1      4754.495247  9.723121e+05
# 2      6976.286456  2.582705e+06
# 3      5075.332000  1.006117e+06
# 4      4459.156019  1.226206e+06
# ...            ...           ...
# 2320   7325.091410  2.674908e+06
# 2321   5659.156615  1.909110e+06
# 2322  22732.905385  8.783519e+06
# 2323   8890.142310  3.028836e+06
# 2324   8338.971957  2.999985e+06
#
# [2325 rows x 13 columns]

# %%
# only keep the columns we need

tracts = tracts[['CTLabel', 'CT2020', 'GEOID']]

# %%
tracts.rename(columns={'GEOID': 'geoid'}, inplace=True)
# Out:
# /var/folders/bp/5dzvdsg55xn25gp9vjh1f4xc0000gn/T/ipykernel_28918/766813932.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tracts.rename(columns={'GEOID': 'geoid'}, inplace=True)

# %%
# find column types

tracts.dtypes
# Out:
# CTLabel    float64
# CT2020       int64
# geoid        int64
# dtype: object

# %%
# join tracts to income based on the geoid using an inner join

income_tracts = pd.merge(income, tracts, on='geoid', how='outer', indicator=True)

# %%
income_tracts._merge.value_counts()

# confirming that all the tracts in the income df are accounted for
# Out:
# _merge
# both          2196
# right_only     129
# left_only        0
# Name: count, dtype: int64

# %%
# only keep the both rows

income_tracts = income_tracts[income_tracts['_merge'] == 'both']

# now I have a dataset I can use to join to the other datasets

# %%
income_tracts.head()
# Out:
#          geoid                           name  median_household_income
# 0  36005000200      Census Tract 2, Bronx, NY                  70867.0  \
# 1  36005000400      Census Tract 4, Bronx, NY                  98090.0
# 2  36005001600     Census Tract 16, Bronx, NY                  40033.0
# 3  36005001901  Census Tract 19.01, Bronx, NY                  55924.0
# 4  36005001902  Census Tract 19.02, Bronx, NY                  60804.0
#
#    B19013001, Error  COUNTY   TRACT  CTLabel  CT2020 _merge
# 0           25423.0     5.0   200.0     2.00     200   both
# 1           18180.0     5.0   400.0     4.00     400   both
# 2            9907.0     5.0  1600.0    16.00    1600   both
# 3           12028.0     5.0  1901.0    19.01    1901   both
# 4           12156.0     5.0  1902.0    19.02    1902   both

# %% [markdown]
# Reading the Open Streets data

# %%
open_streets = pd.read_csv('mean_coords_table_with_geos.csv')

# %%
open_streets['FULL_GEOID'] = open_streets['GEOID']
open_streets
# Out:
#                                               wkt_geom        MEAN_X
# 0    Point (932357.50813676416873932 129799.6779506...  9.323575e+05  \
# 1    Point (952222.48087393492460251 147937.0785196...  9.522225e+05
# 2    Point (957307.78094421629793942 167722.3556344...  9.573078e+05
# 3    Point (961974.16859200922772288 165665.9565205...  9.619742e+05
# 4    Point (962028.83035567402839661 168307.7564461...  9.620288e+05
# ..                                                 ...           ...
# 537  Point (1056074.98569662659429014 158679.738558...  1.056075e+06
# 538  Point (1056284.10559147596359253 158493.067578...  1.056284e+06
# 539  Point (1056446.62167064100503922 158342.209940...  1.056447e+06
# 540  Point (1056606.48847688734531403 158161.324475...  1.056606e+06
# 541  Point (1056766.34396426379680634 157966.613414...  1.056766e+06
#
#             MEAN_Y  object_id       lat        lon            GEOID  STATE
# 0    129799.677951        1.0  40.52279 -74.186652  360850198004041     36  \
# 1    147937.078520      384.0  40.57267 -74.115286  360850134001007     36
# 2    167722.355634      480.0  40.62699 -74.097060  360850059021000     36
# 3    165665.956521      501.0  40.62136 -74.080242  360850029002000     36
# 4    168307.756446        6.0  40.62861 -74.080054  360850033002000     36
# ..             ...        ...       ...        ...              ...    ...
# 537  158679.738558      325.0  40.60192 -73.741347  360811010021009     36
# 538  158493.067578      326.0  40.60141 -73.740596  360811010021003     36
# 539  158342.209940      320.0  40.60099 -73.740012  360811010021000     36
# 540  158161.324475      321.0  40.60050 -73.739439  360811010021000     36
# 541  157966.613415      319.0  40.59996 -73.738865  360811010021000     36
#
#      COUNTY   TRACT  BLOCK       FULL_GEOID
# 0        85   19800   4041  360850198004041
# 1        85   13400   1007  360850134001007
# 2        85    5902   1000  360850059021000
# 3        85    2900   2000  360850029002000
# 4        85    3300   2000  360850033002000
# ..      ...     ...    ...              ...
# 537      81  101002   1009  360811010021009
# 538      81  101002   1003  360811010021003
# 539      81  101002   1000  360811010021000
# 540      81  101002   1000  360811010021000
# 541      81  101002   1000  360811010021000
#
# [542 rows x 12 columns]

# %%
open_streets['GEOID'] = open_streets.GEOID.astype(str).str.slice(0,-4).astype(int)

# %%
open_streets
# Out:
#                                               wkt_geom        MEAN_X
# 0    Point (932357.50813676416873932 129799.6779506...  9.323575e+05  \
# 1    Point (952222.48087393492460251 147937.0785196...  9.522225e+05
# 2    Point (957307.78094421629793942 167722.3556344...  9.573078e+05
# 3    Point (961974.16859200922772288 165665.9565205...  9.619742e+05
# 4    Point (962028.83035567402839661 168307.7564461...  9.620288e+05
# ..                                                 ...           ...
# 537  Point (1056074.98569662659429014 158679.738558...  1.056075e+06
# 538  Point (1056284.10559147596359253 158493.067578...  1.056284e+06
# 539  Point (1056446.62167064100503922 158342.209940...  1.056447e+06
# 540  Point (1056606.48847688734531403 158161.324475...  1.056606e+06
# 541  Point (1056766.34396426379680634 157966.613414...  1.056766e+06
#
#             MEAN_Y  object_id       lat        lon        GEOID  STATE
# 0    129799.677951        1.0  40.52279 -74.186652  36085019800     36  \
# 1    147937.078520      384.0  40.57267 -74.115286  36085013400     36
# 2    167722.355634      480.0  40.62699 -74.097060  36085005902     36
# 3    165665.956521      501.0  40.62136 -74.080242  36085002900     36
# 4    168307.756446        6.0  40.62861 -74.080054  36085003300     36
# ..             ...        ...       ...        ...          ...    ...
# 537  158679.738558      325.0  40.60192 -73.741347  36081101002     36
# 538  158493.067578      326.0  40.60141 -73.740596  36081101002     36
# 539  158342.209940      320.0  40.60099 -73.740012  36081101002     36
# 540  158161.324475      321.0  40.60050 -73.739439  36081101002     36
# 541  157966.613415      319.0  40.59996 -73.738865  36081101002     36
#
#      COUNTY   TRACT  BLOCK       FULL_GEOID
# 0        85   19800   4041  360850198004041
# 1        85   13400   1007  360850134001007
# 2        85    5902   1000  360850059021000
# 3        85    2900   2000  360850029002000
# 4        85    3300   2000  360850033002000
# ..      ...     ...    ...              ...
# 537      81  101002   1009  360811010021009
# 538      81  101002   1003  360811010021003
# 539      81  101002   1000  360811010021000
# 540      81  101002   1000  360811010021000
# 541      81  101002   1000  360811010021000
#
# [542 rows x 12 columns]

# %%
# this gives us the number of open streets per tract

open_streets_count = open_streets[['GEOID']].value_counts()

# %%
# save as a dataframe

open_streets_count = pd.DataFrame(open_streets_count).reset_index()

# %%
open_streets_count
# Out:
#            GEOID  count
# 0    36081038302     14
# 1    36081016900     11
# 2    36061007300     10
# 3    36081101002      9
# 4    36081029100      8
# ..           ...    ...
# 228  36047051800      1
# 229  36047052900      1
# 230  36047055200      1
# 231  36047057300      1
# 232  36085019800      1
#
# [233 rows x 2 columns]

# %%
# open_streets_count.reset_index(inplace=True)

# %%
open_streets_count.rename(columns={'GEOID': 'geoid'}, inplace=True)

# %%
open_streets_count
# Out:
#            geoid  count
# 0    36081038302     14
# 1    36081016900     11
# 2    36061007300     10
# 3    36081101002      9
# 4    36081029100      8
# ..           ...    ...
# 228  36047051800      1
# 229  36047052900      1
# 230  36047055200      1
# 231  36047057300      1
# 232  36085019800      1
#
# [233 rows x 2 columns]

# %%
income_tracts = income_tracts.drop(columns='TRACT')
income_tracts.rename(columns={'CT2020': 'TRACT'}, inplace=True)

# %%
# drop the _merge column

income_tracts.drop(columns=['_merge'], inplace=True)

# %%
income_tracts.head()
# Out:
#          geoid                           name  median_household_income
# 0  36005000200      Census Tract 2, Bronx, NY                  70867.0  \
# 1  36005000400      Census Tract 4, Bronx, NY                  98090.0
# 2  36005001600     Census Tract 16, Bronx, NY                  40033.0
# 3  36005001901  Census Tract 19.01, Bronx, NY                  55924.0
# 4  36005001902  Census Tract 19.02, Bronx, NY                  60804.0
#
#    B19013001, Error  COUNTY  CTLabel  TRACT
# 0           25423.0     5.0     2.00    200
# 1           18180.0     5.0     4.00    400
# 2            9907.0     5.0    16.00   1600
# 3           12028.0     5.0    19.01   1901
# 4           12156.0     5.0    19.02   1902

# %%
open_streets_count
# Out:
#            geoid  count
# 0    36081038302     14
# 1    36081016900     11
# 2    36061007300     10
# 3    36081101002      9
# 4    36081029100      8
# ..           ...    ...
# 228  36047051800      1
# 229  36047052900      1
# 230  36047055200      1
# 231  36047057300      1
# 232  36085019800      1
#
# [233 rows x 2 columns]

# %%
merged = pd.merge(open_streets_count, income_tracts, on='geoid', how='outer', indicator=True)
merged
# Out:
#             geoid  count                               name
# 0     36081038302   14.0                                NaN  \
# 1     36081016900   11.0       Census Tract 169, Queens, NY
# 2     36061007300   10.0      Census Tract 73, New York, NY
# 3     36081101002    9.0   Census Tract 1010.02, Queens, NY
# 4     36081029100    8.0       Census Tract 291, Queens, NY
# ...           ...    ...                                ...
# 2199  36085029106    NaN  Census Tract 291.06, Richmond, NY
# 2200  36085030301    NaN  Census Tract 303.01, Richmond, NY
# 2201  36085030302    NaN  Census Tract 303.02, Richmond, NY
# 2202  36085031902    NaN  Census Tract 319.02, Richmond, NY
# 2203  36085032300    NaN     Census Tract 323, Richmond, NY
#
#       median_household_income  B19013001, Error  COUNTY  CTLabel     TRACT
# 0                         NaN               NaN     NaN      NaN       NaN  \
# 1                     77027.0           15493.0    81.0   169.00   16900.0
# 2                    142409.0           42874.0    61.0    73.00    7300.0
# 3                     38395.0           32774.0    81.0  1010.02  101002.0
# 4                     58226.0            5107.0    81.0   291.00   29100.0
# ...                       ...               ...     ...      ...       ...
# 2199                 127671.0           25994.0    85.0   291.06   29106.0
# 2200                  95913.0            6123.0    85.0   303.01   30301.0
# 2201                  85842.0           18154.0    85.0   303.02   30302.0
# 2202                  76066.0           35257.0    85.0   319.02   31902.0
# 2203                  86471.0           25095.0    85.0   323.00   32300.0
#
#           _merge
# 0      left_only
# 1           both
# 2           both
# 3           both
# 4           both
# ...          ...
# 2199  right_only
# 2200  right_only
# 2201  right_only
# 2202  right_only
# 2203  right_only
#
# [2204 rows x 9 columns]

# %%
merged['_merge'].value_counts()
# Out:
# _merge
# right_only    1971
# both           225
# left_only        8
# Name: count, dtype: int64

# %%
merged.query('name.isna()')
# Out:
#            geoid  count name  median_household_income  B19013001, Error
# 0    36081038302   14.0  NaN                      NaN               NaN  \
# 34   36081017101    4.0  NaN                      NaN               NaN
# 84   36081064102    2.0  NaN                      NaN               NaN
# 120  36085005902    1.0  NaN                      NaN               NaN
# 129  36081019901    1.0  NaN                      NaN               NaN
# 131  36081009900    1.0  NaN                      NaN               NaN
# 153  36061016600    1.0  NaN                      NaN               NaN
# 224  36047044902    1.0  NaN                      NaN               NaN
#
#      COUNTY  CTLabel  TRACT     _merge
# 0       NaN      NaN    NaN  left_only
# 34      NaN      NaN    NaN  left_only
# 84      NaN      NaN    NaN  left_only
# 120     NaN      NaN    NaN  left_only
# 129     NaN      NaN    NaN  left_only
# 131     NaN      NaN    NaN  left_only
# 153     NaN      NaN    NaN  left_only
# 224     NaN      NaN    NaN  left_only

# %%
# show the value counts of the _merge column

merged._merge.value_counts()

# this means that there are five tracts that have open streets but no median household income data
# Out:
# _merge
# right_only    1971
# both           225
# left_only        8
# Name: count, dtype: int64

# %%
# keep only the rows where the _merge column is 'both'

# merged = merged[merged['_merge'] == 'both']

# %%
merged
# Out:
#             geoid  count                               name
# 0     36081038302   14.0                                NaN  \
# 1     36081016900   11.0       Census Tract 169, Queens, NY
# 2     36061007300   10.0      Census Tract 73, New York, NY
# 3     36081101002    9.0   Census Tract 1010.02, Queens, NY
# 4     36081029100    8.0       Census Tract 291, Queens, NY
# ...           ...    ...                                ...
# 2199  36085029106    NaN  Census Tract 291.06, Richmond, NY
# 2200  36085030301    NaN  Census Tract 303.01, Richmond, NY
# 2201  36085030302    NaN  Census Tract 303.02, Richmond, NY
# 2202  36085031902    NaN  Census Tract 319.02, Richmond, NY
# 2203  36085032300    NaN     Census Tract 323, Richmond, NY
#
#       median_household_income  B19013001, Error  COUNTY  CTLabel     TRACT
# 0                         NaN               NaN     NaN      NaN       NaN  \
# 1                     77027.0           15493.0    81.0   169.00   16900.0
# 2                    142409.0           42874.0    61.0    73.00    7300.0
# 3                     38395.0           32774.0    81.0  1010.02  101002.0
# 4                     58226.0            5107.0    81.0   291.00   29100.0
# ...                       ...               ...     ...      ...       ...
# 2199                 127671.0           25994.0    85.0   291.06   29106.0
# 2200                  95913.0            6123.0    85.0   303.01   30301.0
# 2201                  85842.0           18154.0    85.0   303.02   30302.0
# 2202                  76066.0           35257.0    85.0   319.02   31902.0
# 2203                  86471.0           25095.0    85.0   323.00   32300.0
#
#           _merge
# 0      left_only
# 1           both
# 2           both
# 3           both
# 4           both
# ...          ...
# 2199  right_only
# 2200  right_only
# 2201  right_only
# 2202  right_only
# 2203  right_only
#
# [2204 rows x 9 columns]

# %%
# save the merged dataset

merged.to_csv('final_data.csv', index=False)
